# %%
import pandas as pd

# %%
data = pd.read_csv('blockchain_tweets.csv')
data.head()
# Out:
#                              user_name user_location  \
# 0                            Blockwork           NaN
# 1                               Rib-It           NaN
# 2  ❤️LacedWhales (CARDANO POOL: PEACE)           NaN
# 3                    Wiscobus Ntukuyoh        Lagos
# 4                               Rib-It           NaN
#
#                                     user_description  \
# 0  Find a job in blockchain: https://t.co/7X6K6WK...
# 1  🐸 RibIt 2021 YOU are the foundation of our cre...
# 2  1M+ $ADA whale txs laced with ❤️ from La @Reps...
# 3  Crypto Analyst |Crypto ambassador |$FIL,$DASH|...
# 4  🐸 RibIt 2021 YOU are the foundation of our cre...
#
#                 user_created  user_followers  user_friends  user_favourites  \
# 0  2018-02-25 19:11:34+00:00             237           331                2
# 1  2021-09-19 22:05:58+00:00            1819          2221              266
# 2  2020-08-21 11:38:22+00:00             617             3               52
# ...

# %%
# drop all the columns except 'text'
data = data['text']
data.head()
# Out:
# 0    #blockchain Y I N C. C O M is hiring for the f...
# 1    Check out this account on OpenSea https://t.co...
# 2    🐳 #Cardano $ADA Whale ❤️laced!\n💰 Transaction ...
# 3    🌈 Hop over to #Coinstore's App to trade now!!\...
# 4    Check out this account on OpenSea https://t.co...
# Name: text, dtype: object

# %%
# get 300 random tweets
random = data.sample(n=300)
random.head()
# Out:
# 6345    What is BitShares!\n#BitShares #bts #evrazcoin...
# 9105    @crypto @wealth See @polker_PKR Metaverse, whi...
# 9485    @PlantExodus Awesome project\n#Airdrop #Blockc...
# 5042    New nft disponible link in bio\n\n#NFTGiveaway...
# 4885    The next #Bitcoin is the pi network project  ✅...
# Name: text, dtype: object

# %%
# convert the tweets to a list
random = random.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Twitter\Twitter\Machine Learning\test.ipynb Zelle 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Twitter/Twitter/Machine%20Learning/test.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # convert the tweets to a list
# ----> <a href='vscode-notebook-cell:/d%3A/Twitter/Twitter/Machine%20Learning/test.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> random = random.tolist()
#       <a href='vscode-notebook-cell:/d%3A/Twitter/Twitter/Machine%20Learning/test.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> print(random)
#
# AttributeError: 'list' object has no attribute 'tolist'

# %%
print(random)
# Out:
# ['What is BitShares!\n#BitShares #bts #evrazcoin #evrazdex #blockchain #crypto #defi #bitcoin #btc #altcoin #finance #exchange #cash #investment #evrazwallet #innovation #technology #евраз #блокчейн #крипта https://t.co/NuAWZRCyUi', '@crypto @wealth See @polker_PKR Metaverse, which integrates the most advanced deep learning AI algorithms for game characters to create animations/interactions based on player actions to deliver true virtual reality experiences. #Metaverse #BSC\n#Bitcoin\n #poker $PKR  #P2E #NFT #Blockchain', '@PlantExodus Awesome project\n#Airdrop #Blockchain #Playtoearn', 'New nft disponible link in bio\n\n#NFTGiveaway #NFT #NFTCommunity #NFTs #blockchain #Japan #Ethereum #ETH #Cryptomonnaies https://t.co/VH9BLHSsPL', 'The next #Bitcoin is the pi network project  ✅✅ The biggest digital currency is on its way very quickly.\n\n#PiNetwork\n#Bitcoin #Crypto  #ADA #Ethereum  #Coinbase #CoinMarketCap  #Binance #Tesla  #dogecoin #Solana #USDtether\n#fodl #blockchain #shiba \n
# ...
